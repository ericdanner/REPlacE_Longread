# %% [markdown]
# #### Run on R 3.5 as per required packages in script.
# #### Here are the bash comamnds:
# #### Control Polb WT: Worked with no insertion export
# '''
# for getIndelStats.R arg[1]=bamFile arg[2]=sampleName arg[3]=outDir arg[4]=cutSitesFiles
#          arg[5]=sgRNA_list(column (:) separated list of sgRNA ids (must match ids in cutSitesFile)) arg[6]=reference.fasta
# '''
# #### Control WT: Worked with no insertion export
# Rscript getIndelStatsExportinsertionsNreference.R /home/edanner/workspace/V2Seq/AlignmentMiniMap2/Reporter/CntlReporterWT.sorted.bam CntlWTReporter ./output/CntlWTReporter /home/edanner/workspace/V2Seq/Analysis/cutsites/sgRNAs.txt bfp1:bfp2 ../refseqs/reporterwt.fasta
#
# #### Targeted WT:  Worked (also I used bbmap for this alignment)
# Rscript getIndelStatsExportinsertionsNreference.R /home/edanner/workspace/V2Seq/alignmentsBBMap/Reporter/TargetedReporterWTfwd.sorted.bam ReporterTargetedWT ./output/ReporterTargetedWT /home/edanner/workspace/V2Seq/Analysis/cutsites/sgRNAs.txt bfp1:bfp2 ../refseqs/reporterwt.fasta
#
# #### Targeted mCherry: Worked( no insertion)
# Rscript getIndelStatsExportinsertionsNreferenceBlocked.R /home/edanner/workspace/V2Seq/AlignmentMiniMap2/Reporter/TargetedReporterCherry.sorted.bam ReporterTargetedCherry ./output/ReporterTargetedCherry /home/edanner/workspace/V2Seq/Analysis/cutsites/sgRNAs.txt mCherry1:mCherry2 ../refseqs/reportercherry.fasta
#
# #### Targeted Del/Venus: Worked with no insertion export
# Rscript getIndelStatsExportinsertionsNreferenceBlocked.R /home/edanner/workspace/V2Seq/AlignmentMiniMap2/Reporter/TargetedReporterDel.sorted.bam ReporterTargetedDel ./output/ReporterTargetedDel /home/edanner/workspace/V2Seq/Analysis/cutsites/sgRNAs.txt venus1 ../refseqs/reporterdel.fasta

# %% [markdown]
# ### Reporter Replacment Plots

# %%
dfmCherry <- read.table("/home/edanner/workspace/V2Seq/Analysis/output/ReporterTargetedCherry/ReporterTargetedCherry.coverageStats.tsv", header=TRUE)

# %%
layout(matrix(c(1,1,2,3), 2, 2, byrow = TRUE))

plot(dfmCherry$bp, 1-dfmCherry$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "* Resection of Correct Knock-in mCherry alleles",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 1))



#zooming in on the left indel
plot(dfmCherry$bp[825:1025], 1-dfmCherry$delAvg[825:1025],
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection at left cutsite",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 1))

#zoomign in on the right indel
plot(dfmCherry$bp[1657:1857], 1-dfmCherry$delAvg[1657:1857],
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection at Right Cutsite",
     ylab = "% of reads containing the base",
     ylim = c(0, 1))
# Out:
# Plot with title “Resection at Right Cutsite”

# %%
par(mfrow=c(3,1))

plot(dfmCherry$bp, dfmCherry$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "* Resection of Correct Knock-in mCherry alleles",
     ylab = "% of reads containing deletion at base",
     ylim = c(0, 1))

plot(dfmCherry$bp, dfmCherry$insAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = " Insertion of Correct Knock-in mCherry alleles",
     ylab = "% of reads containing ins at base",
     ylim = c(0, 1))

plot(dfmCherry$bp, dfmCherry$indelAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = " Indel Correct Knock-in mCherry alleles",
     ylab = "% of reads containing indel at base",
     ylim = c(0, 1))
# Out:
# Plot with title “ Indel Correct Knock-in mCherry alleles”

# %% [markdown]
# ### CONTROL WT Sequences

# %%
dfBFP <- read.table("/home/edanner/workspace/V2Seq/Analysis/output/CntlWTReporter/CntlWTReporter.coverageStats.tsv", header=TRUE)

# %%
layout(matrix(c(1,1,2,3), 2, 2, byrow = TRUE))

plot(dfBFP$bp, dfBFP$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of WT Sequences",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 1))

plot(dfBFP$bp[825:1025], dfBFP$delAvg[825:1025],
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection at left cutsite",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 1))

#zooming in on the right indel
plot(dfBFP$bp[1923:2123], dfBFP$delAvg[1823:2023],
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection at left cutsite",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 1))
# Out:
# Plot with title “Resection at left cutsite”

# %%
dfBFPTar <- read.table("/home/edanner/workspace/V2Seq/Analysis/output/ReporterTargetedWT/ReporterTargetedWT.coverageStats.tsv", header=TRUE)

# %%
layout(matrix(c(1,1,2,3), 2, 2, byrow = TRUE))

plot(dfBFPTar$bp, 1-dfBFPTar$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of WT Sequences",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 1))

plot(dfBFPTar$bp[825:1025], 1- dfBFPTar$delAvg[825:1025],
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection at left cutsite",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 1))

#zooming in on the right indel
plot(dfBFPTar$bp[1923:2123], 1- dfBFPTar$delAvg[1823:2023],
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection at left cutsite",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 1))
# Out:
# Plot with title “Resection at left cutsite”

# %%
par(mfrow=c(3,1))

plot(dfBFPTar$bp, dfBFPTar$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of WT Sequences",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 1))
plot(dfBFPTar$bp, dfBFPTar$insAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of WT Reporter Seq",
     ylab = "% of reads containing deletion of base",
     ylim = c(0, 1))
plot(dfBFPTar$bp, dfBFPTar$indelAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of WT Reporter Seq",
     ylab = "% of reads containing deletion of base",
     ylim = c(0, 1))
# Out:
# Plot with title “Resection of WT Reporter Seq”

# %% [markdown]
# ### Deletion

# %%
dfVENUS <- read.table("/home/edanner/workspace/V2Seq/Analysis/output/ReporterTargetedDel/ReporterTargetedDel.coverageStats.tsv", header=TRUE)

# %%
layout(matrix(c(1,1,2,3), 2, 2, byrow = TRUE))

plot(dfVENUS$bp, dfVENUS$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of 'Deletion' Sequences",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 1))

#zooming in on the cut site #925bp
plot(dfVENUS$bp[825:1025], dfVENUS$delAvg[825:1025],
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection at left cutsite",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 1))
# Out:
# Plot with title “Resection at left cutsite”

# %%
par(mfrow=c(3,1))

plot(dfVENUS$bp, dfVENUS$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of 'Deletion' Sequences",
     ylab = "% reads with deletion at base",
     ylim = c(0, 1))
#insertion location
plot(dfVENUS$bp, dfVENUS$insAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Insertion Frequency in Deletion Reads",
     ylab = "%  reads with insertion at base",
     ylim = c(0, 1))

#indel
plot(dfVENUS$bp, dfVENUS$indelAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Indel Frequency in Deletion Reads",
     ylab = "% of reads with indel at base",
     ylim = c(0, 1))
# Out:
# Plot with title “Indel Frequency in Deletion Reads”

# %%
par(mfrow=c(3,1))

plot(dfmCherry$bp, dfmCherry$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "* Resection of Correct Knock-in mCherry alleles",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 1))
plot(dfBFPTar$bp, dfBFPTar$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of WT Sequences",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 1))

plot(dfVENUS$bp, dfVENUS$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of 'Deletion' Sequences",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 1))
# Out:
# Plot with title “Resection of 'Deletion' Sequences”

# %%
#exporting the graph above as vector
svg(filename="ReporterTargeted.svg")

par(mfrow=c(3,1))

plot(dfmCherry$bp, dfmCherry$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "* Resection of Correct Knock-in mCherry alleles",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 1))
plot(dfBFPTar$bp, dfBFPTar$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of WT Sequences",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 1))

plot(dfVENUS$bp, dfVENUS$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of 'Deletion' Sequences",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 1))
dev.off()
# Out:
# png
#   2
