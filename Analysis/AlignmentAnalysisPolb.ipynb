# %% [markdown]
# ## Analysis of Alignments

# %%
#Run on R 3.5 as per required packages in script.	
#Here are the bash comamnds:
#Control Polb WT: Worked with no insertion export
Rscript getIndelStatsExportinsertionsNreferenceBlocked.R /home/edanner/workspace/V2Seq/AlignmentMiniMap2/Polb/Cntl_PolbWT.sorted.bam PolbCntlWT ./output/CntlPolbWT /home/edanner/workspace/V2Seq/Analysis/cutsites/sgRNAs.txt pWT1:pWT2 ../refseqs/polbwt.fasta


#Targeted WT:   Worked
Rscript getIndelStatsExportinsertionsNreference.R /home/edanner/workspace/V2Seq/AlignmentMiniMap2/Polb/PolbTargetedWT_REV.sorted.bam PolbTargetedWT ./output/PolbTargetedWT /home/edanner/workspace/V2Seq/Analysis/cutsites/sgRNAs.txt pWT1:pWT2 ../refseqs/polbwt.fasta

#Targeted WT-REV: Worked
Rscript getIndelStatsExportinsertionsNreference.R /home/edanner/workspace/V2Seq/AlignmentMiniMap2/Polb/PolbTargetedWT_REV.sorted.bam PolbTargetedWT_Rev ./output/PolbTargetedWT-REV /home/edanner/workspace/V2Seq/Analysis/cutsites/sgRNAs.txt pWT1:pWT2 ../refseqs/polbwt-rev.fasta

#mCherry Replacement:   Worked
Rscript getIndelStatsExportinsertionsNreference.R /home/edanner/workspace/V2Seq/AlignmentMiniMap2/Polb/TargetedPolbCherry.sorted.bam PolbTargetReplace ./output/PolbTargetedReplace /home/edanner/workspace/V2Seq/Analysis/cutsites/sgRNAs.txt pCherry1:pCherry2 ../refseqs/polbcherry.fasta

#Del: Worked with no insertion export
Rscript getIndelStatsExportinsertionsNreferenceBlocked.R /home/edanner/workspace/V2Seq/AlignmentMiniMap2/Polb/PolbTargetedDel.sorted.bam PolbTargetedDel ./output/PolbTargetedDel /home/edanner/workspace/V2Seq/Analysis/cutsites/sgRNAs.txt pDel1 ../refseqs/polbdel.fasta
# Out:
# Error in parse(text = x, srcfile = src): <text>:4:9: unexpected symbol
# 3: #Control Polb WT: Worked with no insertion export
# 4: Rscript getIndelStatsExportinsertionsNreferenceBlocked.R
#            ^
# Traceback:

# %% [markdown]
# # Polb Replacment Resection Plots

# %%
dfPolbReplace <- read.table("./output/PolbTargetedReplace/PolbTargetReplace.coverageStats.tsv", header=TRUE)

# %%
layout(matrix(c(1,1,2,3), 2, 2, byrow = TRUE))

# Replacement Polb Resection
plot(dfPolbReplace$bp, 1- dfPolbReplace$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of Polb Exon Exchanged Alleles ",
     ylab = "% of reads with base deleted",
     ylim = c(0, 1))

#Zoom in on the left
plot(dfPolbReplace$bp[921:1121], 1-dfPolbReplace$delAvg[921:1121],
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection At Left Junction in Correct Polb Replacement Alleles",
     ylab = "% of reads with deletion of base",
     ylim = c(0, 1))
#Zoom in on the right #left site of cutsite is 2251
plot(dfPolbReplace$bp[2151:2351], 1-dfPolbReplace$delAvg[2151:2351],
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection At Right Junction in Correct Polb Replacement Alleles",
     ylab = "% of reads with deletion of base",
     ylim = c(0, 1))
# Out:
# Plot with title “Resection At Right Junction in Correct Polb Replacement Alleles”

# %%
layout(matrix(c(1,1,2,3), 2, 2, byrow = TRUE))

#Polb Hiros Iinsertion locations
plot(dfPolbReplace$bp, dfPolbReplace$insAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "% of the WT reads containing an insertion at each base",
     ylab = "% of reads containing the base",
     ylim = c(0, 1))

#Zoom in on the left INSERTIONS
plot(dfPolbReplace$bp[921:1121], dfPolbReplace$insAvg[921:1121],
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Insertions at each base Left Junction",
     ylab = "% of reads containing an insertion",
     ylim = c(0, 1))

#Zoom in on the right INSERTIONS
plot(dfPolbReplace$bp[2151:2351], dfPolbReplace$insAvg[2151:2351],
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Insertion at each base position Right Junction",
     ylab = "% of reads containing an insertion",
     ylim = c(0, 1))
# Out:
# Plot with title “Insertion at each base position Right Junction”

# %%
layout(matrix(c(1,1,2,3), 2, 2, byrow = TRUE))


#Polb Indel 
plot(dfPolbReplace$bp, dfPolbReplace$indelAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "% of the WT reads containing an indel at each base",
     ylab = "% of reads containing the base",
     ylim = c(0, 1))

#Zoom in on the left INDEL
plot(dfPolbReplace$bp[921:1121], dfPolbReplace$indelAvg[921:1121],
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "% of the WT reads containing a deletion base",
     ylab = "% of reads containing the base",
     ylim = c(0, 1))

#Zoom in on the right INDEL
plot(dfPolbReplace$bp[2151:2351], dfPolbReplace$indelAvg[2151:2351],
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "% of the WT reads containing a deletion base",
     ylab = "% of reads containing the base",
     ylim = c(0, 1))
# Out:
# Plot with title “% of the WT reads containing a deletion base”

# %% [markdown]
# # WildType Control Polb Plots

# %%
dfCntlPolbWT <- read.csv("./output/CntlPolbWT/PolbCntlWT.coverageStats.csv", header=TRUE)

# %%
par(mfrow=c(3,1))

plot(dfCntlPolbWT$bp, dfCntlPolbWT$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of WT Polb Sequences",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 1))
#insertion
plot(dfCntlPolbWT$bp, dfCntlPolbWT$insAvg,
     type = "h",
     lwd = 1,
     xlab = "Insertion Frequencey",
     main = "Insertions in WT Polb Sequences",
     ylab = "% of reads containing with an Insertion at base",
     ylim = c(0, 1))

#Indel
plot(dfCntlPolbWT$bp, dfCntlPolbWT$indelAvg,
     type = "h",
     lwd = 1,
     xlab = " Indel at specific Base Position",
     main = "Indel of WT Polb Sequences",
     ylab = "% of reads containing with Indel of base",
     ylim = c(0, 1))
# Out:
# Plot with title “Indel of WT Polb Sequences”

# %%
dfPolbWT <- read.table("/home/edanner/workspace/V2Seq/Analysis/output/PolbTargetedWT/PolbTargetedWT.coverageStats.tsv", header=TRUE)
#WT2 Has extra smooth to smooth out the aligner poly-N pileups
dfPolbWT2 <- read.table("/home/edanner/workspace/V2Seq/Analysis/output/PolbTargetedWT/PolbTargetedWT2.coverageStats.csv", header=TRUE)

# %%
layout(matrix(c(1,1,2,3), 2, 2, byrow = TRUE))

plot(dfPolbWT$bp, dfPolbWT$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of WT Polb Sequences",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 1))


#zooming in on the left indel 1021bp
plot(dfPolbWT2$bp[921:1121], dfPolbWT2$delAvg[921:1121],
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection at left cutsite",
     ylab = "% of reads containing with deletion of base",
     ylim = c(0, 0.5))


#zoomign in on the right indel 1428
plot(dfPolbWT2$bp[1328:1528], dfPolbWT2$delAvg[1328:1528],
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection at Right Cutsite",
     ylab = "% of reads containing the base",
     ylim = c(0, 0.5))
# Out:
# Plot with title “Resection at Right Cutsite”

# %%
par(mfrow=c(3,1))


#WT insertions
plot(dfPolbWT$bp, dfPolbWT$insAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Insertions at each base",
     ylab = "% of reads containing the base",
     ylim = c(0, 1))

#WT indels
plot(dfPolbWT$bp, dfPolbWT$indelAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "% of the WT reads containing a deletion at each base",
     ylab = "% of reads containing the base",
     ylim = c(0, 1))
# Out:
# Plot with title “% of the WT reads containing a deletion at each base”

# %% [markdown]
# # Polb Deletion Graphs

# %%
dfPolbDel <- read.table("./output/PolbTargetedDel/PolbTargetedDel.coverageStats.tsv", header=TRUE)

# %%
par(mfrow=c(2,1))

#Polb Deletion
#Resection
plot(dfPolbDel$bp, dfPolbDel$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of Polb Exon Exchanged Alleles ",
     ylab = "% of reads with base deleted",
     ylim = c(0, 1))

#Zoom in on the left #cutsite1021
plot(dfPolbDel$bp[921:1121], dfPolbDel$delAvg[921:1121],
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection At Left Junction in Correct Polb Replacement Alleles",
     ylab = "% of reads with deletion of base",
     ylim = c(0, 1))
# Out:
# Plot with title “Resection At Left Junction in Correct Polb Replacement Alleles”

# %%
par(mfrow=c(3,1))
plot(dfPolbDel$bp, dfPolbDel$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of Polb Exon Exchanged Alleles ",
     ylab = "% of reads with base deleted",
     ylim = c(0, 1))


#Insertions
dfPolbReplace <- read.table("/home/edanner/workspace/V2Seq/Analysis/output/PolbTargetedDel/PolbTargetedDel.coverageStats.tsv", header=TRUE)
plot(dfPolbDel$bp, dfPolbDel$insAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of Polb Exon Exchanged Alleles ",
     ylab = "% of reads with base deleted",
     ylim = c(0, 1))

#INDEL
dfPolbReplace <- read.table("/home/edanner/workspace/V2Seq/Analysis/output/PolbTargetedDel/PolbTargetedDel.coverageStats.tsv", header=TRUE)
plot(dfPolbDel$bp, dfPolbDel$indelAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of Polb Exon Exchanged Alleles ",
     ylab = "% of reads with base deleted",
     ylim = c(0, 1))
# Out:
# Plot with title “Resection of Polb Exon Exchanged Alleles ”

# %% [markdown]
# # This is the Sumamry of the 3 resection Plots

# %%
par(mfrow=c(3,1))

plot(dfPolbWT$bp, dfPolbWT$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of WT Polb Sequences",
     ylab = "% of reads containing base",
     ylim = c(0, 1))
plot(dfPolbReplace$bp, dfPolbReplace$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of Polb Exon Exchanged Alleles ",
     ylab = "% of reads containing base",
     ylim = c(0, 1))


plot(dfPolbDel$bp, dfPolbDel$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of Polb Deletion Alleles ",
     ylab = "% of reads containing base",
     ylim = c(0, 1))
dev.off()
# Out:
# null device
#           1
# Plot with title “Resection of Polb Deletion Alleles ”

# %%
svg(filename="PolbTargeted.svg")

par(mfrow=c(3,1))

plot(dfPolbWT$bp, dfPolbWT$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of WT Polb Sequences",
     ylab = "% of reads containing base",
     ylim = c(0, 1))
plot(dfPolbReplace$bp, dfPolbReplace$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of Polb Exon Exchanged Alleles ",
     ylab = "% of reads containing base",
     ylim = c(0, 1))


plot(dfPolbDel$bp, dfPolbDel$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of Polb Deletion Alleles ",
     ylab = "% of reads containing base",
     ylim = c(0, 1))
dev.off()
# Out:
# png
#   2

# %% [markdown]
# Export the graph as vector. I couldn't get the pdf export to work

# %%
svg(filename="PolbHIROS.svg", 
    width=8, 
    height=3,)

plot(dfPolbReplace$bp, 1- dfPolbReplace$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of Polb Replacement Alleles ",
     ylab = "% of reads containing base",
     ylim = c(0, 1))


dev.off()
# Out:
# png
#   2

# %%
svg(filename="PolbWTResection.svg", 
    width=8.5, 
    height=3,)
plot(dfPolbWT$bp, 1- dfPolbWT$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of WT Polb Sequences",
     ylab = "% of reads containing base",
     ylim = c(0, 1))


dev.off()
# Out:
# png
#   2

# %%
svg(filename="PolbDelResection.svg", 
    width=8, 
    height=3,)
plot(dfPolbDel$bp, 1- dfPolbDel$delAvg,
     type = "h",
     lwd = 1,
     xlab = "Base Position",
     main = "Resection of Polb Deletion Alleles ",
     ylab = "% of reads containing base",
     ylim = c(0, 1))


dev.off()
# Out:
# png
#   2
